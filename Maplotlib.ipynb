# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# functional method
plt.plot(x,y) # showing the plot

# %%
plt.plot(x,y)
plt.show() # Printing out the plot

# %%
# For x label, y label and title
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
plt.plot(x,y)
plt.show()

# %%
# creating subplots
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
# Object Oriented Method
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# Adding the axes and also inserting it
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

# %%
# For playing around and to see how axes changes
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.55,0.2,0.3,0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes2.plot(y,x)

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes2.plot(y,x)

axes2.set_xlabel('X Label of smaller one')
axes2.set_ylabel('Y Label of smaller one')
axes2.set_title('SMALLER PLOT')

axes1.set_xlabel('X Label of larger one')
axes1.set_ylabel('Y Label of larger one')
axes1.set_title('LARGER PLOT')
# Out:
# Text(0.5, 1.0, 'LARGER PLOT')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.55,0.2,0.3,0.3])

axes2.plot(x,y)
axes1.plot(y,x)

axes2.set_xlabel('X Label of smaller one')
axes2.set_ylabel('Y Label of smaller one')
axes2.set_title('SMALLER PLOT')

axes1.set_xlabel('X Label of larger one')
axes1.set_ylabel('Y Label of larger one')
axes1.set_title('LARGER PLOT')
# Out:
# Text(0.5, 1.0, 'LARGER PLOT')

# %%
# for creating rows and columns of plot
fig,axes = plt.subplots(nrows = 1, ncols = 2)

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)
# itering the items
for plots in axes:
    plots.plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)

axes[1].plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x,y)
axes[0].set_title("First Plot")

axes[1].plot(y,x)
axes[1].set_title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %%
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
# Method 1 for figuresize
fig = plt.figure(figsize=(5,3))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
# Method 2 for figuresize
fig,axes = plt.subplots(nrows = 2,ncols = 1,figsize = (5,3))

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %%
# DPI stands for dots per inches for eg. 200 DPI means 200hx200w size of image
fig = plt.figure(figsize=(4,2),dpi = 200)

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 2,ncols = 1,figsize = (5,3), dpi = 150)

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %%
fig.savefig("My_plot.png")

# %%
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.plot(y,x)

# %%
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2)
ax.plot(x,x**3)

# %%
# Legends are a useful way to label data series plotted on a graph.
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label = 'Square of X')
ax.plot(x,x**3,label = 'Cube of Y')

ax.legend()

# %%
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label = 'Square of X')
ax.plot(x,x**3,label = 'Cube of Y')

ax.legend(loc = 'upper right')

# %%
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label = 'Square of X')
ax.plot(x,x**3,label = 'Cube of Y')

ax.legend(loc = 1)

# %%
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label = 'Square of X')
ax.plot(x,x**3,label = 'Cube of Y')

ax.legend(loc = (0.1,0.1))

# %%
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label = 'Square of X')
ax.plot(x,x**3,label = 'Cube of Y')

ax.legend(loc = 0)

# %%
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label = 'Square of X')
ax.plot(x,x**3,label = 'Cube of Y')

ax.legend(loc = 'best')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "red" )

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "#FF6347" ) #Tomato

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "blue" )

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "#ADD8E6" ) #lightblue

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 3) # lw = linewidth here it is thrice of lw

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 3,alpha = 0.5) # alpha set the transparency rate here it is 50 %

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 3,linestyle = "--")

# %%
len(x)
# Out:
# 11

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 3,ls = "--")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 3,ls = ":")

# %% [markdown]
# #### supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 3,ls = "dashdot")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 0.5,ls = "--",marker = "*")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 0.5,ls = "--",marker = "+")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 0.5,ls = "--",marker = ".")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 0.5,ls = "--",marker = "1")

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 0.5,ls = "--",marker = "1",markersize = 15)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 0.5,ls = "--",marker = "o",markersize = 15)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 0.5,ls = "--",marker = "o",markersize = 15,markerfacecolor = 'red',markeredgewidth = 3,
        markeredgecolor = 'brown')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 2,ls = "--")

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)

# %%
plt.scatter(x,y)

# %%
plt.hist(x,y,)
# Out:
# (array([1., 1., 3., 3., 3., 0., 0., 0., 0., 0.]),
#  array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#         20.25, 25.  ]),
#  <BarContainer object of 10 artists>)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([10.,  8.,  9.,  9., 11.,  9., 12.,  6., 13., 13.]),
#  array([ 15. , 112.5, 210. , 307.5, 405. , 502.5, 600. , 697.5, 795. ,
#         892.5, 990. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);
